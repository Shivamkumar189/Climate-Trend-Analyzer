# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/climate_data.csv", parse_dates=["date"])
df.head()
# Out:
#         date  temperature  rainfall   humidity
# 0 2015-01-01    25.971111  2.794857  85.411080
# 1 2015-01-02    26.081485  2.858689  71.150435
# 2 2015-01-03    24.713847  4.721500  76.321138
# 3 2015-01-04    29.563617  1.529893  69.586836
# 4 2015-01-05    25.607912  1.584259  57.326022

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2922 entries, 0 to 2921
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2922 non-null   datetime64[ns]
#  1   temperature  2922 non-null   float64
#  2   rainfall     2922 non-null   float64
#  3   humidity     2922 non-null   float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 91.4 KB
#                       date  temperature     rainfall     humidity
# count                 2922  2922.000000  2922.000000  2922.000000
# mean   2018-12-31 12:00:00    25.060554     4.036885    65.386521
# min    2015-01-01 00:00:00     9.786556     0.062335    40.014108
# 25%    2016-12-31 06:00:00    18.437459     1.966033    52.802231
# 50%    2018-12-31 12:00:00    24.938461     3.396208    65.413905
# 75%    2020-12-30 18:00:00    31.797396     5.323184    78.129879
# max    2022-12-31 00:00:00    40.754926    20.818528    89.994943
# std                    NaN     7.322720     2.839797    14.547994

# %%
plt.figure(figsize=(12,5))
plt.plot(df['date'], df['temperature'])
plt.title("Temperature Trend")
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(df['date'], df['rainfall'])
plt.title("Rainfall Trend")
plt.show()
